# %%
# ##Factorial

# def fac(num):
#     if num<0:
#         return "Factorial not defined for negative"
#     elif num<=1:
#         return 1
#     else:
#         return num*fac(num-1)


# print(fac(10))
# print(fac(-1))
# print(fac(0))


## Largest

# def larg(num):
#     if len(set(num))==1:
#         return "No"
#     else:
#         return max(num)

# print(larg([1,2,3,4,5,10]))
# print(larg([5,5,5,5]))

##second largest

# def sndlrg(num):
#     if len(set(num))==1:
#         return "No"
#     else:
#         lg=max(num)
#         num.remove(lg)
#         return max(num)

# print(sndlrg([1,2,3,4,5,6]))
# print(sndlrg([5,5,5,5]))
# print(sndlrg([1,2,3,4,4,5,6,6,9]))

##even odd

# def e_o(num):
#     if num%2==0:
#         return "even"
#     else:
#         return "odd"

# print(e_o(12))
# print(e_o(13))

##palindrome

# def palindrome(num):
#     if str(num)==str(num).lower()[::-1]:
#         return True
#     else:
#         return False

# print(palindrome("abba"))
# print(palindrome("abcdba"))
# print(palindrome("1221"))
# print(palindrome(1221))


##is prime

# def is_prime(sti):
    
#     if str(sti).isalpha():
#         return "Input not integer"
#     sti=int(sti)
#     if sti<=1:
#         return False
#     for i in range (2,int(sti**0.5)+1):
#         if sti%i==0:
#             return False
#     return True
# print(is_prime(17))
# print(is_prime("2"))
# print(is_prime("10"))
# print(is_prime("17"))
# print(is_prime("a"))

##perfect square
# import math
# def pft(sti):
    
#     if str(sti).isalpha():
#         return False
#     sti=int(sti)
#     sq=math.sqrt(sti)
#     if sq*sq==sti:
#         return True
#     else:
#         return False
    
# print(pft(9))
# print(pft(10))
# print(pft(5))
# print(pft(25))
# print(pft("9"))

##Distance calculator

def calcu(chk,num,num):
    if chk==
# Out:
# True
# True
# False
# True
# Input not integer
# True
# False
# False
# True
# True
